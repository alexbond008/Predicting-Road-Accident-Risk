# %%
import numpy as np
import pandas as pd
import seaborn as sns
import os
import matplotlib.pyplot as plt

# %%
# Load the dataset
train = pd.read_csv('playground-series-data/train.csv')
test = pd.read_csv('playground-series-data/test.csv')
accidentid = train['id']

# Display basic information about the datasets
print(train.info())
sns.heatmap(train.isnull(), cbar=False)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 517754 entries, 0 to 517753
# Data columns (total 14 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   id                      517754 non-null  int64
#  1   road_type               517754 non-null  object
#  2   num_lanes               517754 non-null  int64
#  3   curvature               517754 non-null  float64
#  4   speed_limit             517754 non-null  int64
#  5   lighting                517754 non-null  object
#  6   weather                 517754 non-null  object
#  7   road_signs_present      517754 non-null  bool
#  8   public_road             517754 non-null  bool
#  9   time_of_day             517754 non-null  object
#  10  holiday                 517754 non-null  bool
#  11  school_season           517754 non-null  bool
#  12  num_reported_accidents  517754 non-null  int64
#  13  accident_risk           517754 non-null  float64
# ...

# %% [markdown]
# ## 📊 Dataset Overview
#
# | Metric | Details |
# | :--- | :--- |
# | **Rows (train)** | 517,754 |
# | **Columns** | 14 (including **accident_risk** as target) |
# | **Test Set** | Same structure, but no target variable |
# | **Missing Values** | None (clean dataset) |
#
# ---
#
# ## 🎯 Target Variable and Problem Type
#
# * **Target:** `accident_risk` (continuous float)
# * **Problem Type:** Regression (as the target is continuous)
# * **Evaluation Metric:** **Root Mean Squared Error (RMSE)**
#
# ---
#
# ## 🔑 Feature Types
#
# ### Categorical Features
# * `road_type`
# * `lighting`
# * `weather`
# * `time_of_day`
#
# ### Binary (Boolean) Features
# * `road_signs_present`
# * `public_road`
# * `holiday`
# * `school_season`
#
# ### Numeric (Int/Float) Features
# * `num_lanes`
# * `curvature`
# * `speed_limit`
# * `num_reported_accidents`

# %%
sns.boxplot(x='road_type',y='accident_risk',data=train)
# Out:
# <Axes: xlabel='road_type', ylabel='accident_risk'>

# %%
sns.boxplot(x='lighting',y='accident_risk',data=train)
# Out:
# <Axes: xlabel='lighting', ylabel='accident_risk'>

# %%
sns.boxplot(x='time_of_day',y='accident_risk',data=train)
# Out:
# <Axes: xlabel='time_of_day', ylabel='accident_risk'>

# %%
sns.boxplot(x='weather',y='accident_risk',data=train)
# Out:
# <Axes: xlabel='weather', ylabel='accident_risk'>

# %%
sns.boxplot(x='road_signs_present',y='accident_risk',data=train)
# Out:
# <Axes: xlabel='road_signs_present', ylabel='accident_risk'>
